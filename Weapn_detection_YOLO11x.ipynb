# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
# Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# ...
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 8.9.7.29
#     Uninstalling nvidia-cudnn-cu12-8.9.7.29:
#       Successfully uninstalled nvidia-cudnn-cu12-8.9.7.29
# ...

# %%
# !nvidia-smi
# Out:
# Mon Nov  4 09:53:15 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off | 00000000:01:00.0  On |                  N/A |
# |  0%   36C    P8              34W / 370W |    570MiB / 24576MiB |     26%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24252MiB)
# Setup complete ✅ (20 CPUs, 62.6 GB RAM, 227.8/273.1 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
# !pip3 install --upgrade "jax[cuda12]"==0.4.28
# Out:
# ...
#   Using cached nvidia_cudnn_cu12-8.9.7.29-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
# Using cached nvidia_cudnn_cu12-8.9.7.29-py3-none-manylinux1_x86_64.whl (704.7 MB)
# ...
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.4.1+cu121 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 8.9.7.29 which is incompatible.
# ...

# %%
# !yolo task=detect mode=train data=/home/avidmech/Gun_detetcion/data.yaml model="yolo11x.pt" epochs=40 imgsz=640 batch=16
# Out:
# ...
# 100%|█████████████████████████████████████████| 109M/109M [02:14<00:00, 854kB/s]
# New https://pypi.org/project/ultralytics/8.3.27 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24252MiB)
# ...

# %%
# !yolo task=detect mode=val model="/home/avidmech/runs/detect/train/weights/best.pt" data=/home/avidmech/Gun_detetcion/data.yaml
# Out:
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24252MiB)
# YOLO11x summary (fused): 464 layers, 56,829,334 parameters, 0 gradients, 194.4 GFLOPs
# val: Scanning /home/avidmech/Gun_detetcion/valid/labels.cache... 2122 images, 0
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       2122       2594      0.755      0.547      0.649       0.34
#                      0       2122       2594      0.755      0.547      0.649       0.34
# Speed: 0.2ms preprocess, 13.6ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to runs/detect/val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model= /home/avidmech/runs/detect/train/weights/best.pt conf=0.25 source=/home/avidmech/Gun_detetcion/test/images save=True
# Out:
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24252MiB)
# YOLO11x summary (fused): 464 layers, 56,829,334 parameters, 0 gradients, 194.4 GFLOPs
#
# image 1/2122 /home/avidmech/Gun_detetcion/test/images/396492783-1599737974_jpeg_jpg.rf.44a8730f0856bb75bbc8f96ab2a63203.jpg: 640x640 (no detections), 15.8ms
# image 2/2122 /home/avidmech/Gun_detetcion/test/images/396492783-1599737974_jpeg_jpg.rf.5955eba13ea29bbb6c51e23d6ae2040c.jpg: 640x640 (no detections), 15.8ms
# image 3/2122 /home/avidmech/Gun_detetcion/test/images/396492783-1599737974_jpeg_jpg.rf.a242b8f432053980bd46540d47e22da7.jpg: 640x640 (no detections), 14.8ms
# image 4/2122 /home/avidmech/Gun_detetcion/test/images/396492783-1599737974_jpeg_jpg.rf.cfa8cf60e53288f6848a31dec05e6f9d.jpg: 640x640 (no detections), 14.9ms
# image 5/2122 /home/avidmech/Gun_detetcion/test/images/396492783-1599737974_jpeg_jpg.rf.d2c65359a8b3d2098b1b483d0cf3f377.jpg: 640x640 (no detections), 15.1ms
# ...
